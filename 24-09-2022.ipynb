# %%
import numpy as np
import pandas as pd
fb=pd.read_csv('Football_TEAM.csv')

# %%
fb
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#1
fb['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#2
len(fb['Team'])
# Out:
# 16

# %%
fb
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#3
len(fb.columns)
# Out:
# 35

# %%
#4
a=fb[['Team','Yellow Cards','Red Cards']]
discipline=pd.DataFrame(a)
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
#5
fb.sort_values(['Red Cards','Yellow Cards'],ascending=False)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 6                Greece      5                8                18
# 9                Poland      2               15                23
# 11  Republic of Ireland      1                7                12
# 7                 Italy      6               34                45
# 10             Portugal      6               22                42
# 13                Spain     12               42                33
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 14               Sweden      5               17                19
# 4                France      3               22                24
# 12               Russia      5                9                31
# 3               England      5               11                18
# 8           Netherlands      2               12                36
# ...

# %%
#6
fb['Yellow Cards'].mean()
# Out:
# 7.4375

# %%
#7
fb[fb['Goals']>6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
#8
fb[fb['Team'].str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
#9
fb.iloc[::,:7]
# Out:
#     Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0                           32             0              0
# 1                           39             0              0
# 2                           27             1              0
# 3                           40             0              0
# 4                           65             1              0
# 5                           80             2              1
# 6                           32             1              1
# 7                          110             2              0
# 8                           60             2              0
# 9                           48             0              0
# 10                          82             6              0
# 11                          28             0              0
# 12                          59             2              0
# 13                         100             0              1
# 14                          39             3              0
# ...

# %%
#10
fb.iloc[::,:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#11
a=fb.set_index('Team',inplace=False)
a.loc[['England','Italy','Russia'],['Shooting Accuracy']]
# Out:
#         Shooting Accuracy
# Team
# England             50.0%
# Italy               43.0%
# Russia              22.5%

# %%
#12
desc_order=fb.sort_values(by=['Goals'],ascending=False)
desc_order.head(1)
# Out:
#      Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 13  Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 13             83        19            11          0       17        17
#
#     Players Used
# 13            18
#
# [1 rows x 35 columns]

# %%
#13
Desc_passing=fb.sort_values('Shooting Accuracy',ascending=False)
Desc_passing.head(5)
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 13    Spain     12               42                33             55.9%
# 0   Croatia      4               13                12             51.9%
# 2   Denmark      4               10                10             50.0%
# 3   England      5               11                18             50.0%
# 5   Germany     10               32                32             47.8%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 13            16.0%                         100             0              1
# 0             16.0%                          32             0              0
# 2             20.0%                          27             1              0
# 3             17.2%                          40             0              0
# 5             15.6%                          80             2              1
#
# ...
